# %% [markdown]
# ## WebScraping II: the reckoning

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import math

# %% [markdown]
# ### Requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.post("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason", data={})
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# #### Status Codes
#
#
# * 200: Everything went okay and the result has been returned (if any).
# * 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# * 400: The server thinks you made a bad request. This happens when you don’t send along the right data, among other things.
# * 401: You are not properly authenticated.
# * 403: The resource you’re trying to access is forbidden: you don’t have the right permissions to get it.
# * 404: The resource you tried to access doesn't exist.
# * 503: The server can't handle the request.

# %%
r = requests.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2021-01-01,&user_rating=6.5,&num_votes=100,')
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Content-Type': 'text/html;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'Server', 'Date': 'Thu, 07 Oct 2021 16:58:59 GMT', 'x-amz-rid': 'TPPYMBFTD1GY7VA5F1WV', 'Set-Cookie': 'uu=eyJpZCI6InV1NTViZTY0ZGIxMzI5NDRlOWEyNDUiLCJwcmVmZXJlbmNlcyI6eyJmaW5kX2luY2x1ZGVfYWR1bHQiOmZhbHNlfX0=; Domain=.imdb.com; Expires=Tue, 25-Oct-2089 20:13:06 GMT; Path=/; Secure, session-id=000-0000000-0000000; Domain=.imdb.com; Expires=Tue, 25-Oct-2089 20:13:06 GMT; Path=/; Secure, session-id-time=2264345939; Domain=.imdb.com; Expires=Tue, 25-Oct-2089 20:13:06 GMT; Path=/; Secure', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Security-Policy': "frame-ancestors 'self' imdb.com *.imdb.com *.media-imdb.com withoutabox.com *.withoutabox.com amazon.com *.amazon.com amazon.co.uk *.amazon.co.uk amazon.de *.amazon.de translate.google.com images.google.com www.google.com www.google.co.uk search.aol.com bing.com www.bing.com", 'Content-Language': 'en-US', 'Strict-Transport-Security': 'max-age=47474747; includeSubDomains; preload', 'Vary': 'Content-Type,Accept-Encoding,X-Amzn-CDN-Cache,X-Amzn-AX-Treatment,User-Agent', 'Permissions-Policy': 'interest-cohort=()', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 b94073a62e6e677b12e3b808b42901ec.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'HYD50-C2', 'X-Amz-Cf-Id': 'nM3VNgFoQK5jUe9Z9EvCvhJGMmLTmzdIZH8UC85_27HIDjwh6SMRMA=='}

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='session-id', value='000-0000000-0000000', port=None, port_specified=False, domain='.imdb.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=3781109586, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id-time', value='2264345939', port=None, port_specified=False, domain='.imdb.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=3781109586, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='uu', value='eyJpZCI6InV1NTViZTY0ZGIxMzI5NDRlOWEyNDUiLCJwcmVmZXJlbmNlcyI6eyJmaW5kX2luY2x1ZGVfYWR1bHQiOmZhbHNlfX0=', port=None, port_specified=False, domain='.imdb.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=3781109586, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %% [markdown]
# /search/title/?title_type=feature&release_date=2021-01-01,2021-12-31&user_rating=6.5,&num_votes=100,&start=151&ref_=adv_nxt

# %%
# firt getting the number of total results

soup = BeautifulSoup(r.content, 'html.parser')

soup.find('div', attrs={'class': 'desc'}).find('span').get_text().split()[-2]
# Out:
# '516'

# %%
total_results = int(soup.find('div', attrs={'class': 'desc'}).find('span').get_text().split()[-2])
total_results
# Out:
# 516

# %%
starts = range(1, total_results, 50) # because, 50 items per page
list(starts)
# Out:
# [1, 51, 101, 151, 201, 251, 301, 351, 401, 451, 501]

# %%
r = requests.get(f'https://www.imdb.com/search/title/?title_type=feature&release_date=2021-01-01,2021-12-31&user_rating=6.5,&num_votes=100,&start=1&ref_=adv_nxt')
soup = BeautifulSoup(r.content, 'html.parser')
soup.find_all('div', attrs={'class': 'lister-item-content'})[0]
# Out:
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt2382320/">No Time to Die</a>
# <span class="lister-item-year text-muted unbold">(2021)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">UA</span>
# <span class="ghost">|</span>
# <span class="runtime">163 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Adventure, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="7.6" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>7.6</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt2382320" id="urv_tt2382320">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt2382320">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt2382320|imdb|7.6|7.6|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 7.6/10 (48,601 votes) - click stars to rate">
# <meta content="7.6" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="48601" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 106.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">7.6</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt2382320/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">70        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
# James Bond has left active service. His peace is short-lived when Felix Leiter, an old friend from the CIA, turns up asking for help, leading Bond onto the trail of a mysterious villain armed with dangerous new technology.</p>
# <p class="">
#     Director:
# <a href="/name/nm1560977/">Cary Joji Fukunaga</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0185819/">Daniel Craig</a>,
# <a href="/name/nm1869101/">Ana de Armas</a>,
# <a href="/name/nm1785339/">Rami Malek</a>,
# <a href="/name/nm2244205/">Léa Seydoux</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="48601" name="nv">48,601</span>
# </p>
# </div>

# %%
try:
    x = int('a')
except:
    print('hello')
# Out:
# hello

# %%
if int('a') == 'a':
    print('123')
else:
    print('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-b57ca98badfa> in <module>
# ----> 1 if int('a') == 'a':
#       2     print('123')
#       3 else:
#       4     print('hello')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# To get all the pages:

movies = []

for start in starts:
    try:
        r = requests.get(f'https://www.imdb.com/search/title/?title_type=feature&release_date=2021-01-01,2021-12-31&user_rating=6.5,&num_votes=100,&start={start}&ref_=adv_nxt')
        soup = BeautifulSoup(r.content, 'html.parser')
        movies += soup.find_all('div', attrs={'class': 'lister-item-content'})
    except:
        print(f'Error on page {start}.')
        continue
    
len(movies)


# To get all the pages:

movies = []

for start in starts:
    
    r = requests.get(f'https://www.imdb.com/search/title/?title_type=feature&release_date=2021-01-01,2021-12-31&user_rating=6.5,&num_votes=100,&start={start}&ref_=adv_nxt')
    
    if r.status_code == 200:
        soup = BeautifulSoup(r.content, 'html.parser')
        movies += soup.find_all('div', attrs={'class': 'lister-item-content'})
    else:
        print(f'Error on page {start}.')
        continue
    
len(movies)
# Out:
# 515

# %%
movies[0]
# Out:
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt2382320/">No Time to Die</a>
# <span class="lister-item-year text-muted unbold">(2021)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">UA</span>
# <span class="ghost">|</span>
# <span class="runtime">163 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Action, Adventure, Thriller            </span>
# </p>
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="7.6" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>7.6</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt2382320" id="urv_tt2382320">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt2382320">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt2382320|imdb|7.6|7.6|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 7.6/10 (48,601 votes) - click stars to rate">
# <meta content="7.6" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# <meta content="48601" itemprop="ratingCount"/>
# <span class="rating-bg"> </span>
# <span class="rating-imdb" style="width: 106.4px"> </span>
# <span class="rating-stars">
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>1</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>2</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>3</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>4</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>5</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>6</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>7</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>8</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>9</span></a>
# <a href="/register/login?why=vote" rel="nofollow" title="Register or login to rate this title"><span>10</span></a>
# </span>
# <span class="rating-rating"><span class="value">7.6</span><span class="grey">/</span><span class="grey">10</span></span>
# <span class="rating-cancel"><a href="/title/tt2382320/vote" rel="nofollow" title="Delete"><span>X</span></a></span>
#  </div>
# </div>
# </div>
# <div class="inline-block ratings-metascore">
# <span class="metascore favorable">70        </span>
#         Metascore
#             </div>
# </div>
# <p class="text-muted">
# James Bond has left active service. His peace is short-lived when Felix Leiter, an old friend from the CIA, turns up asking for help, leading Bond onto the trail of a mysterious villain armed with dangerous new technology.</p>
# <p class="">
#     Director:
# <a href="/name/nm1560977/">Cary Joji Fukunaga</a>
# <span class="ghost">|</span>
#     Stars:
# <a href="/name/nm0185819/">Daniel Craig</a>,
# <a href="/name/nm1869101/">Ana de Armas</a>,
# <a href="/name/nm1785339/">Rami Malek</a>,
# <a href="/name/nm2244205/">Léa Seydoux</a>
# </p>
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="48601" name="nv">48,601</span>
# </p>
# </div>

# %%
titles = []
ratings = []
genres = []
runtimes = []
links = []

for i,movie in enumerate(movies):
    titles.append(movie.find('h3').find('a').get_text())
    ratings.append(movie.find('strong').get_text())
    if movie.find('span', attrs={'class': 'genre'}) != None:
        genres.append(movie.find('span', attrs={'class': 'genre'}).get_text(strip=True))
    else:
        print(titles[-1] + ' has no genre')
        genres.append('no genre')
    links.append('http://www.imdb.com' + movie.find('h3', attrs={'class': 'lister-item-header'}).find('a').get('href'))
    if movie.find('span', attrs={'class': 'runtime'}) != None:
        runtimes.append(movie.find('span', attrs={'class': 'runtime'}).get_text())
        print(i,titles[-1])
    else:
        print(movie.find('span', attrs={'class': 'runtime'}))
        runtimes.append('Not informed.')
# Out:
# 0 No Time to Die
# 1 Dune
# 2 Free Guy
# 3 The Many Saints of Newark
# 4 Venom: Let There Be Carnage
# 5 Shang-Chi and the Legend of the Ten Rings
# 6 The Last Duel
# 7 The Suicide Squad
# 8 Cruella
# 9 Halloween Kills
# 10 The Green Knight
# 11 My Little Pony: A New Generation
# 12 Titane
# 13 The French Dispatch
# 14 Black Widow
# 15 Jungle Cruise
# 16 Pig
# 17 Last Night in Soho
# 18 Wrath of Man
# 19 Copshop
# 20 The Eyes of Tammy Faye
# 21 The Tomorrow War
# 22 Nobody
# 23 Zack Snyder's Justice League
# 24 The Power of the Dog
# 25 CODA
# 26 Lamb
# 27 Shershaah
# 28 The Electrical Life of Louis Wain
# 29 Luca
# 30 Stillwater
# 31 Chehre
# 32 Raya and the Last Dragon
# 33 Benedetta
# 34 Respect
# 35 Bhoot Police
# 36 Toma
# 37 Old Henry
# 38 Vivo
# 39 The Medium
# 40 The Witcher: Nightmare of the Wolf
# 41 The Mauritanian
# 42 No Sudden Move
# 43 In the Heights
# 44 Love Story
# 45 Ich bin dein Mensch
# 46 Shiddat
# 47 Blue Bayou
# 48 Le bal des folles
# 49 Fear Street: 1978
# 50 The Last Letter from Your Lover
# 51 Belfast
# 52 Judas and the Black Messiah
# 53 Mass
# 54 Midnight
# 55 Boku no Hero Academia: World Heroes Mission
# 56 The Mitchells vs the Machines
# 57 Cherry
# 58 Together
# 59 The Dig
# 60 Verdens verste menneske
# 61 Fear Street: 1666
# 62 Oxygène
# 63 Babardeala cu bucluc sau porno balamuc
# 64 C'mon C'mon
# 65 Red Rocket
# 66 12 Mighty Orphans
# 67 Qismat 2
# 68 Small Engine Repair
# 69 Passing
# 70 Eiffel
# 71 Bergman Island
# 72 Fatherhood
# 73 Doraibu mai kâ
# 74 Wish Dragon
# 75 Palmer
# 76 If I Can't Have Love, I Want Power
# 77 Rise of the Footsoldier: Origins
# 78 People Just Do Nothing: Big in Japan
# None
# 80 Nitram
# 81 Mimi
# 82 Mortal Kombat Legends: Battle of the Realms
# 83 Come from Away
# 84 Nou fo
# 85 Helmet
# 86 Pleasure
# 87 Boîte noire
# 88 Sunny
# 89 Seungriho
# 90 Malcolm & Marie
# 91 Rurôni Kenshin: Sai shûshô - The Beginning
# 92 The Auschwitz Report
# 93 Memoria
# 94 Firebird
# 95 Sweetheart
# 96 Shin Evangelion Gekijôban
# 97 Here Today
# 98 Vortex
# 99 È stata la mano di Dio
# 100 Moxie
# 101 Maestro
# 102 Haseen Dillruba
# 103 Together Together
# 104 The White Tiger
# 105 Bad Trip
# 106 Rurôni Kenshin: Sai shûshô - The Final
# 107 Maixabel
# 108 Petite maman
# 109 Happier Than Ever: A Love Letter to Los Angeles
# 110 Ryû to sobakasu no hime
# 111 The Map of Tiny Perfect Things
# 112 Land
# 113 Lift
# 114 The Fallout
# 115 Man of God
# 116 Kaanekkaane
# 117 Blue Miracle
# 118 Raame Aandalum Raavane Aandalum
# 119 Chal Mera Putt 3
# 120 Trollhunters: Rise of the Titans
# 121 Schachnovelle
# 122 Ferry
# 123 Republic
# 124 The Sadness
# 125 Star-Crossed: The Film
# 126 Implanted
# 127 Long Story Short
# 128 Margrete den første
# 129 Sarpatta Parambarai
# 130 Swan Song
# 131 I onde dager
# 132 Mogadishu
# 133 De uskyldige
# 134 Gekijouban Nanatsu no Taizai: Hikari ni Norowareshi Mono-tachi
# 135 Mad God
# 136 #Home
# 137 Necista krv: Greh predaka
# 138 Noche de fuego
# 139 Recalled
# 140 Plan B
# 141 Hytti nro 6
# 142 Les Olympiades, Paris 13e
# 143 Seetharaam Benoy Case Number Eighteen
# 144 Born a Champion
# 145 Azor
# 146 Die Heimsuchung
# 147 The Last Bus
# 148 The Man with the Answers
# 149 Language Lessons
# 150 Kodiyil Oruvan
# 151 Downfalls High
# 152 200: Halla Ho
# 153 The Cursed
# 154 State of Siege: Temple Attack
# 155 L'événement
# 156 De Veroordeling
# 157 Xuan ya zhi shang
# 158 Competencia oficial
# 159 Sivakumarin Sabadham
# 160 Nr. 10
# None
# 162 Aakashavaani
# 163 14 Phere
# 164 Nebenan
# 165 2gether: The Movie
# 166 The Priest
# 167 Fabian oder Der Gang vor die Hunde
# 168 Le sommet des dieux
# 169 Karnan
# 170 Haathi Mere Saathi
# 171 Gûzen to sôzô
# 172 Moosa Jatt
# 173 Murina
# 174 Malik
# 175 Tokyo Revengers
# 176 Întregalde
# 177 Le Guide de la famille parfaite
# 178 Seetimaarr
# 179 Rudra Thandavam
# 180 The Journey
# 181 Kuruthi
# 182 Mijn beste vriendin Anne Frank
# 183 Zeby nie bylo sladów
# 184 Xin shen bang: Ne Zha chong sheng
# 185 Charming the Hearts of Men
# 186 Dang nan ren lian ai shi
# 187 Délicieux
# 188 Tesciowie
# None
# 190 To Olivia
# 191 Grosse Freiheit
# 192 Skater Girl
# 193 Dikkiloona
# 194 Palma
# 195 Ninjababy
# 196 The Novice
# 197 Bhramam
# 198 Thimmarusu: Assignment Vali
# 199 Ajeeb Daastaans
# 200 Kaamelott - Premier volet
# 201 Master
# 202 Petrovy v grippe
# 203 Kasada Thapara
# 204 Pagglait
# 205 Loco por ella
# 206 Ji hun
# 207 Toxikoma
# 208 Kagittan Hayatlar
# 209 Nail Polish
# 210 Silence: Can You Hear It
# 211 Sweet & Sour
# 212 Clairevoyant
# 213 Drishyam 2
# 214 Qui rido io
# 215 Kaadan
# 216 Bem Bom
# 217 Smagen af sult
# 218 Joji
# 219 Kidô senshi Gandamu: Senkô no Hasauei
# 220 A Chiara
# 221 Friendship
# 222 Raja Raja Chora
# 223 Nayattu
# 224 On the Count of Three
# 225 First Signal
# 226 Illusions perdues
# 227 Ras vkhedavt, rodesac cas vukurebt?
# 228 Kaagaz
# 229 Ternet Ninja 2
# 230 Onoda, 10 000 nuits dans la jungle
# 231 Where Is Anne Frank
# 232 June
# 233 Juzni vetar 2: Ubrzanje
# 234 Thittam Irandu
# 235 Mission Possible
# 236 Gekijouban Bishoujo Senshi Sailor Moon Eternal
# 237 The Pebble and the Boy
# 238 Jockey
# 239 Gintama: The Final
# 240 Najmro: Kocha, kradnie, szanuje
# 241 El Planeta
# 242 Mandela
# 243 Hive
# 244 Sherni
# 245 Droste no hate de bokura
# 246 Luzzu
# 247 The Demented
# 248 The Thing: O Regresso
# 249 Tunka Tunka
# 250 Hanataba Mitai na ki wo Shita
# 251 Asmee
# 252 Limbo
# 253 Orey Bamardhi
# 254 Marfa
# 255 Sundari
# 256 Munshigiri
# 257 Zebra Girl
# 258 Gully Rowdy
# 259 My True Fairytale
# 260 Ingenting å le av
# 261 Cousins
# 262 Sokea mies joka ei halunnut nähdä Titanicia
# 263 The Knower
# 264 Panchhi
# 265 Gameboys: The Movie
# 266 Unclenching the Fists
# 267 America Latina
# 268 Mukhosh
# 269 Bai She 2: Qing She jie qi
# 270 The Great Indian Kitchen
# 271 Ni hao, Li Huan Ying
# 272 Korô no chi: Level 2
# 273 Pagten
# 274 After Masks
# 275 Yaar Anmulle Returns
# 276 Brother's Keeper
# 277 Hotel Coppelia
# 278 Chavalas
# 279 A Stand Worthy of Men (wa'fet regala)
# 280 Sheng xia wei lai
# 281 Narappa
# 282 Rang De
# 283 Potato Dreams of America
# 284 Dear Megha
# 285 The Box
# 286 Wish You
# 287 B.A. Pass 3
# 288 The Ultimate Playlist of Noise
# 289 One
# 290 Some of Our Stallions
# 291 The Book of Fish
# 292 Motherly
# 293 Endless Rain
# 294 Narasimhapuram
# 295 Vakeel Saab
# 296 Chakra
# 297 Maro Prasthanam
# 298 Networker Baire
# 299 Sridevi Soda Center
# 300 Operation Java
# 301 Cinderella
# 302 Die Frau des Piloten
# 303 One for the Road
# 304 Zátopek
# 305 Marathon
# 306 Ali & the Queens
# 307 Cosmic Radio
# 308 Crazy Uncles
# 309 Kaiserschmarrndrama
# 310 Ksheera Sagara Madhanam
# 311 Faactory
# 312 Luizenmoeder - De film
# 313 Marvelous and the Black Hole
# 314 Octonauts: The Ring of Fire
# 315 Ninnila Ninnila
# 316 Jathi Ratnalu
# 317 Ikkat
# 318 Uppena
# 319 Munduvareda Adhyaya
# 320 Koozhangal
# 321 Donny's Bar Mitzvah
# 322 House Arrest
# 323 Kala
# 324 Cosas imposibles
# 325 Meitantei Conan: Hiiro no dangan
# 326 Krack
# 327 Groufie
# 328 Zero to Hero
# 329 Vaazhl
# 330 Maara
# 331 Hvor kragerne vender
# 332 Aarkkariyam
# 333 Naandhi
# 334 Zombie Reddy
# 335 Flight
# 336 Mugguru Monagallu
# The Wet Ones has no genre
# None
# 338 Bannerghatta
# 339 Deyyam
# 340 Chaitanyam
# 341 Idhe Maa Katha
# None
# 343 Jedini izlaz
# 344 A (Ad Infinitum)
# 345 Lihvar
# 346 Zuk seoi piu lau
# 347 Thaen
# 348 Methagu
# 349 Sampai Ajal Memisahkan
# 350 Janowar
# 351 Saving Shuli
# 352 Lanke
# 353 Mangalavara Rajaadina
# 354 Swagatam
# 355 Charlotte Moon Mysteries: Green on the Greens
# 356 Batya
# 357 Tempt Raja
# 358 Charlie Boy
# 359 Merise Merise
# Choo Mandhirakaali has no genre
# 360 Choo Mandhirakaali
# 361 Devineni
# 362 G - Zombie
# 363 Teddy
# 364 Red
# 365 Ekip Oyunu
# 366 Hello, Stranger: The Movie
# 367 Ja
# 368 Golata istina za grupa Zhiguli
# 369 Nee Jathaga
# 370 Rengeteg - Mindenhol látlak
# None
# 372 Check
# 373 Stop-Zemlia
# 374 Vellam
# 375 Rehana Maryam Noor
# 376 Zero Nine
# 377 Gaali Sampath
# 378 Anugraheethan Antony
# 379 Parigettu Parigettu
# 380 Plantados
# 381 Cinema Bandi
# 382 Death of a Girlfriend
# 383 Nefutbol
# 384 Rickshawala
# 385 Blackpink: The Show
# 386 Malaysia to Amnesia
# 387 Money Fight
# 388 Roberrt
# 389 Ek Mini Katha
# 390 Varthamanam
# 391 Kilit
# 392 Y
# 393 Hero
# None
# 395 Plan B
# 396 Vellai Yaanai
# 397 Mentés másképp
# 398 Mr & Miss
# 399 Meitantei Conan: Hiiro no fuzai shômei
# 400 Power Play
# None
# 402 Al Tercer Día
# 403 Cheruvaina Dooramaina
# 404 Lamb of God: The Concert Film
# 405 My King
# 406 Sara's
# Így vagy tökéletes has no genre
# 407 Így vagy tökéletes
# 408 Ammaa Ki Boli
# 409 Climax
# 410 Play Back
# 411 Yuvarathnaa
# 412 Aelay
# 413 Kalathil Sandhippom
# 414 Kabadadaari
# 415 Consequence Karma
# 416 Romeo & Juliet
# 417 Shukra
# 418 Brandy Diaries
# 419 Kamali from Nadukkaveri
# 420 Ghar Pe Bataao
# 421 Santhoshathinte Onnam Rahasyam
# 422 True
# 423 GST (God Saithan Technology)
# 424 Pratidwandi
# 425 Thellavarithe Guruvaram
# 426 Rewind
# None
# 428 Death and Bowling
# 429 Héliopolis
# 430 Nuvvunte Naa Jathaga
# 431 Refl3ct
# 432 Dictionary
# 433 Machaan
# 434 Anbirkiniyal
# 435 Thirike
# 436 Pachchis
# 437 Vay Babam Vay!
# 438 C/O Kaadhal
# 439 Jessu Jordaar
# 440 Forest monster
# 441 Wo de jie jie
# 442 15/07 Safak Vakti
# 443 MAD [in]
# 444 Madison and the Happiness Jar
# 445 Cyanide Mallika
# 446 Jamun
# 447 30 Rojullo Preminchadam Ela
# 448 Happy's
# 449 Dreams on Fire
# 450 Sreekaram
# None
# 452 Fight
# 453 Czarna owca
# 454 Lines
# 455 Case No 130/2016
# 456 Major Dron and the plague doctor
# 457 Sobat Ambyar
# None
# 459 Super Heroes: The Movie
# 460 Pulse
# 461 Super Over
# 462 Suryasthamayam
# 463 Ee Kathalo Paathralu Kalpitam
# None
# 465 Cycle
# 466 Guduputani
# 467 Tangra Blues
# 468 Bo Gia
# 469 A1 Express
# 470 Balamitra
# 471 I Am Meera
# 472 Kadhanika
# 473 Jathiya Rahadari
# 474 Shaadi Mubarak
# 475 The Kennedy Incident
# 476 Koshtoneer
# 477 Unicorn
# 478 The Killer
# Kalaposhakulu has no genre
# None
# 480 Valasa
# 481 Pranavam
# 482 Trayam
# 483 Photo-Prem
# 484 Viraat
# None
# 486 Nuvvante Pichhe
# 487 MMOF
# None
# None
# 490 Kode Muruga
# 491 Bomma Adirindi Dhimma Tirigindi
# None
# 493 O Ammayi Crime Story
# 494 Amma Deevena
# 495 Vaanku
# 496 Çilgin Ortak
# None
# 498 Vittalwadi
# 499 Al Maht
# 500 Ieandavi
# 501 Proklyatyy chinovnik
# 502 Gaurav Gupta: Market Down Hai
# 503 Emotional Fool
# 504 Jeene Ki Umeed Tumse Hi
# 505 Fish and Puddle
# 506 Pappur Biye
# 507 The Crying Steppe
# None
# 509 Jeevnane Natka Samy
# 510 Ms. Preethi
# 511 Raktha Gulabi
# 512 Check Post 1995
# 513 Nerealnyi KOPets
# 514 L'incontro

# %%
x = min(len(titles), len(ratings), len(genres), len(runtimes))

# %%
dct = {'title': titles[:x], 'rating': ratings[:x], 'genre': genres[:x], 'runtime': runtimes[:x], 'link': links[:x]}

df = pd.DataFrame.from_dict(dct)
df
# Out:
#                            title rating                        genre  runtime  \
# 0                 No Time to Die    7.6  Action, Adventure, Thriller  163 min
# 1                           Dune    8.4     Action, Adventure, Drama  155 min
# 2                       Free Guy    7.3    Action, Adventure, Comedy  115 min
# 3      The Many Saints of Newark    6.5                 Crime, Drama  120 min
# 4    Venom: Let There Be Carnage    6.6    Action, Adventure, Sci-Fi   97 min
# ..                           ...    ...                          ...      ...
# 510                  Ms. Preethi    7.3                        Drama   89 min
# 511                Raktha Gulabi    8.8                        Crime  132 min
# 512              Check Post 1995    7.5                        Crime   67 min
# 513             Nerealnyi KOPets    6.7                       Comedy  115 min
# 514                   L'incontro    7.4                        Drama   90 min
#
#                                       link
# 0     http://www.imdb.com/title/tt2382320/
# 1     http://www.imdb.com/title/tt1160419/
# 2     http://www.imdb.com/title/tt6264654/
# 3     http://www.imdb.com/title/tt8110232/
# 4     http://www.imdb.com/title/tt7097896/
# ..                                     ...
# 510  http://www.imdb.com/title/tt15465096/
# 511  http://www.imdb.com/title/tt14311868/
# 512  http://www.imdb.com/title/tt15500298/
# 513  http://www.imdb.com/title/tt13188590/
# 514  http://www.imdb.com/title/tt14273334/
#
# [515 rows x 5 columns]

# %%
links[:1]
# Out:
# ['http://www.imdb.com/title/tt2382320/']

# %%
for link in links[:2]:
    r = requests.get(link)
    soup = BeautifulSoup(r.content, 'html.parser')
    soup1 = soup.find('li', attrs={'class':'ipc-metadata-list__item'})
    directors = [element.get_text() for element in soup1.find_all('a', attrs={'class':'ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link'})]
#     directors = [element.get_text() for element in soup.find_all('a', attrs={'class':'ipc-metadata-list__item'})]
#     directors = [element.get_text() for element in soup.find('div', attrs={'class': 'credit_summary_item'}).find_all('a')]
#     print(soup.find('a', attrs={'class':'ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link'}).get_text())
    print(directors)
# Out:
# ['Cary Joji Fukunaga']
# ['Denis Villeneuve']

# %%
directors = []
for movie in movies[:9]:
    directors.append([element.strip().replace(',', '') for element in movie.find('p', attrs={'class':''}).get_text().strip().split('|')[0].split('\n')[1:-1]])

# %%
directors, titles[:9]
# Out:
# ([['Cary Joji Fukunaga'],
#   ['Denis Villeneuve'],
#   ['Shawn Levy'],
#   ['Alan Taylor'],
#   ['Andy Serkis'],
#   ['Destin Daniel Cretton'],
#   ['Ridley Scott'],
#   ['James Gunn'],
#   ['Craig Gillespie']],
#  ['No Time to Die',
#   'Dune',
#   'Free Guy',
#   'The Many Saints of Newark',
#   'Venom: Let There Be Carnage',
#   'Shang-Chi and the Legend of the Ten Rings',
#   'The Last Duel',
#   'The Suicide Squad',
#   'Cruella'])

# %%
movie.find('p', attrs={'class':''}).get_text().strip().split('|')[0].split('\n')[1:-1]
# Out:
# ['Craig Gillespie']

# %%
from time import sleep
for i in range(5):
    print(i)
    sleep(2)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# cron
