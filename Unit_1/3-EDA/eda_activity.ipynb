# %% [markdown]
# ### Activity 1
#
# Refer to the file files_for_activities/merged_clean_ver1.csv for this exercise.
#
# - Import the merged_clean_ver1.csv file.
# - Check the data types of all columns in the dataframe.
# - Use the describe method on only the float type columns.
#
# #### Debate
# - What is the difference between population mean and sample mean.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('merged_clean_ver1.csv')

# %%
data
# Out:
#       Unnamed: 0      id state gender  median_home_val  \
# 0              0   44060    FL      M      1158.437751
# 1              1   96093    IL      M       537.000000
# 2              2   43333    FL      F       725.000000
# 3              3   21885    NC      M      1158.437751
# 4              4  190108    FL      F       995.000000
# ...          ...     ...   ...    ...              ...
# 3988         996   66762    MI      F       632.000000
# 3989         997    6443    FL      M       595.000000
# 3990         998  151175    CA      F      2707.000000
# 3991         999  151504    CA      M      2666.000000
# 3992        1000   74303    MI      M       444.000000
#
#       median_household_income  ic2  ic3  ic4    ic5    avggift  target_d
# 0                         392  430  466  520  21975  28.000000     100.0
# 1                         365  415  410  473  19387   5.666667       7.0
# 2                         301  340  361  436  18837   4.111111       5.0
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                   int64
# id                           int64
# state                       object
# gender                      object
# median_home_val            float64
# median_household_income      int64
# ic2                          int64
# ic3                          int64
# ic4                          int64
# ic5                          int64
# avggift                    float64
# target_d                   float64
# dtype: object

# %%
data[['target_d', 'avggift']].describe(percentiles=[0.3,0.6,0.9])
# Out:
#           target_d      avggift
# count  3993.000000  3993.000000
# mean     15.665036    11.785117
# std      12.703041    10.172672
# min       1.000000     2.260870
# 30%      10.000000     7.714286
# 50%      14.000000    10.000000
# 60%      15.000000    11.500000
# 90%      25.000000    20.000000
# max     200.000000   450.000000

# %%
data_sample = data.sample(frac=0.2)

# %%
data_sample['target_d'].mean()
# Out:
# 15.857784730913641

# %%
data['target_d'].mean()
# Out:
# 15.665036313548711

# %%
data.describe()
# Out:
#                    id state gender  median_home_val  median_household_income  \
# count     3993.000000  3984   3993      3993.000000              3993.000000
# unique            NaN    52     10              NaN                      NaN
# top               NaN    CA      F              NaN                      NaN
# freq              NaN   749   2080              NaN                      NaN
# mean     98929.308039   NaN    NaN      1158.437751               351.622840
# std      58179.839090   NaN    NaN      1033.485773               168.488445
# min         12.000000   NaN    NaN         0.000000                 0.000000
# 25%      46153.000000   NaN    NaN       548.000000               239.000000
# 50%     101432.000000   NaN    NaN       803.000000               318.000000
# 75%     151653.000000   NaN    NaN      1349.000000               425.000000
# max     191779.000000   NaN    NaN      5982.000000              1500.000000
#
# ...

# %% [markdown]
# ### Activity 2
#
# (Keep working on the same file.)
#
# - Get the numeric data.
# - Use the describe() method on the numeric data in the DataFrame.
# - Print the median.
# - Print IQR.

# %%
data._get_numeric_data()
# Out:
#       Unnamed: 0      id  median_home_val  median_household_income  ic2  ic3  \
# 0              0   44060      1158.437751                      392  430  466
# 1              1   96093       537.000000                      365  415  410
# 2              2   43333       725.000000                      301  340  361
# 3              3   21885      1158.437751                      401  407  399
# 4              4  190108       995.000000                      252  280  316
# ...          ...     ...              ...                      ...  ...  ...
# 3988         996   66762       632.000000                      279  336  339
# 3989         997    6443       595.000000                      252  263  262
# 3990         998  151175      2707.000000                      507  504  538
# 3991         999  151504      2666.000000                      535  609  612
# 3992        1000   74303       444.000000                      225  264  269
#
#       ic4    ic5    avggift  target_d
# ...

# %%
data.select_dtypes(include=[int, float])
# Out:
#       Unnamed: 0      id  median_home_val  median_household_income  ic2  ic3  \
# 0              0   44060      1158.437751                      392  430  466
# 1              1   96093       537.000000                      365  415  410
# 2              2   43333       725.000000                      301  340  361
# 3              3   21885      1158.437751                      401  407  399
# 4              4  190108       995.000000                      252  280  316
# ...          ...     ...              ...                      ...  ...  ...
# 3988         996   66762       632.000000                      279  336  339
# 3989         997    6443       595.000000                      252  263  262
# 3990         998  151175      2707.000000                      507  504  538
# 3991         999  151504      2666.000000                      535  609  612
# 3992        1000   74303       444.000000                      225  264  269
#
#       ic4    ic5    avggift  target_d
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0             id  median_home_val  median_household_income  \
# count  3993.000000    3993.000000      3993.000000              3993.000000
# mean    499.431255   98929.308039      1158.437751               351.622840
# std     288.332533   58179.839090      1033.485773               168.488445
# min       0.000000      12.000000         0.000000                 0.000000
# 25%     250.000000   46153.000000       548.000000               239.000000
# 50%     499.000000  101432.000000       803.000000               318.000000
# 75%     749.000000  151653.000000      1349.000000               425.000000
# max    1001.000000  191779.000000      5982.000000              1500.000000
#
#                ic2          ic3          ic4            ic5      avggift  \
# count  3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean    400.713248   399.876283   444.732031   16456.413724    11.785117
# ...

# %%
data.describe().T['50%']
# Out:
# Unnamed: 0                    499.0
# id                         101432.0
# median_home_val               803.0
# median_household_income       318.0
# ic2                           366.0
# ic3                           365.0
# ic4                           410.0
# ic5                         14356.0
# avggift                        10.0
# target_d                       14.0
# Name: 50%, dtype: float64

# %%
data.median()
# Out:
# Unnamed: 0                    499.0
# id                         101432.0
# median_home_val               803.0
# median_household_income       318.0
# ic2                           366.0
# ic3                           365.0
# ic4                           410.0
# ic5                         14356.0
# avggift                        10.0
# target_d                       14.0
# dtype: float64

# %%
summary = data.describe().T
summary['IQR'] = summary['75%'] - summary['25%']
summary['IQR']
# Out:
# Unnamed: 0                    499.000000
# id                         105500.000000
# median_home_val               801.000000
# median_household_income       186.000000
# ic2                           194.000000
# ic3                           193.000000
# ic4                           203.000000
# ic5                          7644.000000
# avggift                         7.241071
# target_d                       10.000000
# Name: IQR, dtype: float64

# %%
data
# Out:
#       Unnamed: 0      id state gender  median_home_val  \
# 0              0   44060    FL      M      1158.437751
# 1              1   96093    IL      M       537.000000
# 2              2   43333    FL      F       725.000000
# 3              3   21885    NC      M      1158.437751
# 4              4  190108    FL      F       995.000000
# ...          ...     ...   ...    ...              ...
# 3988         996   66762    MI      F       632.000000
# 3989         997    6443    FL      M       595.000000
# 3990         998  151175    CA      F      2707.000000
# 3991         999  151504    CA      M      2666.000000
# 3992        1000   74303    MI      M       444.000000
#
#       median_household_income  ic2  ic3  ic4    ic5    avggift  target_d
# 0                         392  430  466  520  21975  28.000000     100.0
# 1                         365  415  410  473  19387   5.666667       7.0
# 2                         301  340  361  436  18837   4.111111       5.0
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0             id  median_home_val  median_household_income  \
# count  3993.000000    3993.000000      3993.000000              3993.000000
# mean    499.431255   98929.308039      1158.437751               351.622840
# std     288.332533   58179.839090      1033.485773               168.488445
# min       0.000000      12.000000         0.000000                 0.000000
# 25%     250.000000   46153.000000       548.000000               239.000000
# 50%     499.000000  101432.000000       803.000000               318.000000
# 75%     749.000000  151653.000000      1349.000000               425.000000
# max    1001.000000  191779.000000      5982.000000              1500.000000
#
#                ic2          ic3          ic4            ic5      avggift  \
# count  3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean    400.713248   399.876283   444.732031   16456.413724    11.785117
# ...

# %% [markdown]
# ### Activity 3
#
# Refer to the file files_for_activities/merged_clean_ver2.csv for this exercise.
#
# - Load data from the merged_clean_ver2.csv file.
# - Plot Pearson Correlation Heatmap.
# - Plot Spearman Correlation Heatmap.
# - Plot Kendall Correlation Heatmap.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('merged_clean_ver2.csv')

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(data.corr(method='pearson'), annot=True)
plt.show()

# %%
sns.heatmap(data.corr('pearson'), annot=True)
plt.show()

# %%
sns.heatmap(data.corr(method='spearman'), annot=True)
plt.show()

# %%
sns.heatmap(data.corr(method='kendall'), annot=True)
plt.show()
