# %% [markdown]
# ### Activity 1

# %% [markdown]
# Refer to the file files_for_activities/file1.csv for this exercise.
#
# - Load data (file1.csv) in a new Jupyter notebook.
# - Write the code to clean the columns 'ic4' and 'ic5' of null values in the dataframe.
# - Use the head() to check the new dataframe.
# - Debate
# - Is it better to fill null values with the mean or with the median?
# - Can we drop all rows with null values?

# %%
import pandas as pd

# %%
data = pd.read_csv('file1.csv')

# %%
data
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
#          IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0      430.0  466  28.000000      1  1901     C2     100.0
# 1      415.0  410   5.666667      0     0     T2       7.0
# 2      340.0  361   4.111111      0  2501     C2       5.0
# 3      407.0  399  27.277778      0  2208     T2      38.0
# 4      280.0  316   6.000000     28     0     C2       5.0
# ...      ...  ...        ...    ...   ...    ...       ...
# 1002   609.0  579  11.666667      0     0     C2      15.0
# 1003  1004.0  893  20.000000      1  4401     S1      20.0
# 1004   413.0  404   7.300000      0  4404     C2      10.0
# 1005   419.0  476  16.400000      1  5001     S2      23.0
# 1006   277.0  292   9.818182      2  2201     S2      12.0
#
# [1007 rows x 17 columns]

# %%
data.columns = data.columns.str.lower()

# %%
data
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
#          ic2  ic3    avggift  tcode   dob domain  target_d
# 0      430.0  466  28.000000      1  1901     C2     100.0
# 1      415.0  410   5.666667      0     0     T2       7.0
# 2      340.0  361   4.111111      0  2501     C2       5.0
# 3      407.0  399  27.277778      0  2208     T2      38.0
# 4      280.0  316   6.000000     28     0     C2       5.0
# ...      ...  ...        ...    ...   ...    ...       ...
# 1002   609.0  579  11.666667      0     0     C2      15.0
# 1003  1004.0  893  20.000000      1  4401     S1      20.0
# 1004   413.0  404   7.300000      0  4404     C2      10.0
# 1005   419.0  476  16.400000      1  5001     S2      23.0
# 1006   277.0  292   9.818182      2  2201     S2      12.0
#
# [1007 rows x 17 columns]

# %%
data.isna().sum()
# Out:
# controln     0
# state        0
# gender      40
# hv1          2
# ic1          0
# ic4          1
# hvp1         0
# ic5          0
# pobc1        0
# pobc2        0
# ic2          1
# ic3          0
# avggift      0
# tcode        0
# dob          0
# domain       0
# target_d     0
# dtype: int64

# %%
data[data['ic4'].isna()==False]
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
#          ic2  ic3    avggift  tcode   dob domain  target_d
# 0      430.0  466  28.000000      1  1901     C2     100.0
# 1      415.0  410   5.666667      0     0     T2       7.0
# 2      340.0  361   4.111111      0  2501     C2       5.0
# 3      407.0  399  27.277778      0  2208     T2      38.0
# 4      280.0  316   6.000000     28     0     C2       5.0
# ...      ...  ...        ...    ...   ...    ...       ...
# 1002   609.0  579  11.666667      0     0     C2      15.0
# 1003  1004.0  893  20.000000      1  4401     S1      20.0
# 1004   413.0  404   7.300000      0  4404     C2      10.0
# 1005   419.0  476  16.400000      1  5001     S2      23.0
# 1006   277.0  292   9.818182      2  2201     S2      12.0
#
# [1006 rows x 17 columns]

# %%
data['ic4'] = data['ic4'].fillna(data['ic4'].mean())

# %%
data.isna().sum()
# Out:
# controln     0
# state        0
# gender      40
# hv1          2
# ic1          0
# ic4          0
# hvp1         0
# ic5          0
# pobc1        0
# pobc2        0
# ic2          1
# ic3          0
# avggift      0
# tcode        0
# dob          0
# domain       0
# target_d     0
# dtype: int64

# %%
data.head()
# Out:
#    controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      ic2  ic3    avggift  tcode   dob domain  target_d
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %% [markdown]
# ### Activity 2

# %% [markdown]
# Refer to the file files_for_activities/merged_clean_ver1.csv for this exercise.
#
# - Import the data from merged_clean_ver1.csv as a dataframe. There would be a column with the sequence of numbers (to the left of column id). Drop that column(s).
# - Check the column state for null values. Replace those null values with the state that is represented largest number of times in that column
#
# #### Lambda Expression:
#
# - Create a simple lambda expression to add three numbers. Take those three numbers as input from the user. (Since you will accept only numbers as valid inputs, check this example to see how to do it.)
# - Define a list as lst = [1,2,3,4,5,6,7,8,10]. Write a lambda expression to find the cube of a number. Use that lambda expression to find the cube of every number in the list. Define a list comprehension for this question.

# %%
data = pd.read_csv('merged_clean_ver1.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'state', 'gender', 'median_home_val',
#        'median_household_income', 'ic4', 'hvp1', 'ic5', 'pobc1', 'pobc2',
#        'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain', 'target_d'],
#       dtype='object')

# %%
data
# Out:
#       Unnamed: 0      id state  gender median_home_val  \
# 0              0   44060    FL       M          AAA896
# 1              1   96093    IL       M          537.00
# 2              2   43333    FL       F          725.00
# 3              3   21885    NC       M         AAA1095
# 4              4  190108    FL       F          995.00
# ...          ...     ...   ...     ...             ...
# 1943        1010  161838    CA       F            1953
# 1944        1011  161838    CA       F            1953
# 1945        1012  138311    AZ  Female            1708
# 1946        1013  123469    TX       M             561
# 1947        1014  135341    AZ  Female             700
#
#       median_household_income    ic4  hvp1    ic5  pobc1  pobc2    ic2  ic3  \
# 0                         392  520.0     7  21975      6     16  430.0  466
# 1                         365  473.0     0  19387      1     89  415.0  410
# 2                         301  436.0     3  18837     11     17  340.0  361
# 3                         401  413.0     7  14014      1     74  407.0  399
# 4                         252  348.0     0  17991      5      6  280.0  316
# ...                       ...    ...   ...    ...    ...    ...    ...  ...
# 1943                      304  380.0    47  13811     25     43  353.0  337
# 1944                      304  380.0    47  13811     25     43  353.0  337
# 1945                      437  684.0    36  29098      7     19  586.0  551
# 1946                      493  540.0     1  16623      5     68  529.0  506
# 1947                      205  295.0     0  12713      9     12  221.0  276
#
#         avggift  tcode   dob domain  target_d
# 0     28.000000      1  1901     C2     100.0
# 1      5.666667      0     0     T2       7.0
# 2      4.111111      0  2501     C2       5.0
# 3     27.277778      0  2208     T2      38.0
# 4      6.000000     28     0     C2       5.0
# ...         ...    ...   ...    ...       ...
# 1943  13.500000      0  4212     C2      14.0
# 1944  13.500000      0  4212     C2      14.0
# 1945   9.769231      2  1403     S1      20.0
# 1946   5.200000      0     0     T2       5.0
# 1947  12.857143      0     0     C2      12.0
#
# [1948 rows x 18 columns]

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.isna().sum()
# Out:
# id                         0
# state                      0
# gender                     0
# median_home_val            0
# median_household_income    0
# ic4                        0
# hvp1                       0
# ic5                        0
# pobc1                      0
# pobc2                      0
# ic2                        0
# ic3                        0
# avggift                    0
# tcode                      0
# dob                        0
# domain                     0
# target_d                   0
# dtype: int64

# %%
data['state'].mode()
# Out:
# 0    CA
# dtype: object

# %%
data['state'].value_counts()
# Out:
# CA            298
# FL            164
# TX            155
# IL            127
# MI            114
# California     92
# NC             89
# WA             78
# GA             61
# WI             56
# MO             55
# IN             53
# OR             52
# MN             44
# SC             39
# CO             38
# KY             35
# TN             33
# LA             29
# AL             29
# OK             27
# IA             26
# AZ             24
# KS             24
# Cali           23
# NM             22
# AR             18
# NV             16
# Arizona        16
# ID             15
# NE             14
# SD             13
# MS             11
# HI              8
# MT              8
# UT              8
# Tennessee       8
# WY              7
# ND              7
# CT              2
# NJ              2
# MD              2
# AK              2
# NY              1
# AP              1
# VA              1
# AE              1
# Name: state, dtype: int64

# %%
data['state'] = data['state'].fillna('CA')

# %%
y = lambda a,b,c: a+b+c
y(1,2,3)
# Out:
# 6

# %%
input_1 = int(input())
input_2 = int(input())
input_3 = int(input())
# Out:
#  10
#  20
#  30

# %%
g,h,i
# Out:
# (10, 20, 30)

# %%
y(g,h,i)
# Out:
# 60

# %%
type(g)
# Out:
# int

# %%
g
# Out:
# 6

# %%
lst = [1,2,3,4,5,6,7,8,10]
cube = lambda x: x*x*x

# %%
new_lst = [cube(item) for item in lst if item%2==1]
new_lst
# Out:
# [1, 27, 125, 343]

# %% [markdown]
# ### Activity 3

# %% [markdown]
# Try to convert these functions into lambda functions.
#
# ```python
# def function_1(a,b):
#     c=a+b
#     return c
# ```
#
# ```python
# def function_2(a,b):
#     c=0
#     for i in range(a):
#         c+=2*b
#     return c
# ```
#
# ```python
# def function_3(a,b):
#     c=0
#     if a>3:
#         c=12
#     else:
#         c='Too big.'
#     return c
# ```

# %%
y = lambda a,b: a+b

# %%
y(1,2)
# Out:
# 3

# %%
# a = 3
# b = 2

# %%
y = lambda a,b: sum([2*b for i in range(a)])
y(3,2)
# Out:
# 12

# %%
y = lambda a,b: 12 if a>3 else 'Too big.'

# %%
y(4,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-2a787c622120> in <module>
# ----> 1 y(4,3)
#
# TypeError: <lambda>() takes 1 positional argument but 2 were given

# %%
# y = lambda a,b: a+b
# y = lambda a,b: sum([2*b for i in range(a)])
# y = lambda a,b: 12 if a>3 else 'Too big.'

# %%
y(2,3)
# Out:
# 'Too big.'

# %%
l = [1, 2, 3, 4, 5]
['yes' if v == 1 else 'no' if v == 2 else 'idle' for v in l]
# Out:
# ['yes', 'no', 'idle', 'idle', 'idle']

# %%
# if v == 1:
#     "yes"
# else:
#     if v == 2:
#         "no"
#     else:
#         "idle"

# %% [markdown]
# ### Activity 4
# Use the same notebook in which you already loaded merged_clean_ver1.csv.
#
# - Create a user-defined method to clean the column state in the dataframe.
# - Use string functions to standardize the states to uppercase and use the strip function to clean the strings as well.

# %%
# data['state'].value_counts()
data['state'].unique()
# Out:
# array(['FL', 'IL', 'NC', 'TX', 'NV', 'CA', 'Cali', 'AP', 'KS', 'IN', 'MT',
#        'WI', 'MO', 'HI', 'UT', 'GA', 'WA', 'ID', 'CT', 'AL', 'ND', 'SC',
#        'IA', 'CO', 'LA', 'OR', 'SD', 'TN', 'NM', 'AZ', 'MN', 'KY', 'OK',
#        'NJ', 'NE', 'MI', 'AR', 'California', 'MS', 'NY', 'Arizona', 'WY',
#        'Tennessee', 'MD', 'AK', 'VA', 'AE'], dtype=object)

# %%
def clean(x):
    if x.lower().startswith('cali'):
        return 'CA'
    elif x.lower().startswith('tenne'):
        return 'TN'
    elif x.lower().startswith('ari'):
        return 'AZ'
    else:
        return x

# %%
data['clean_state'] = data['state'].apply(clean)

# %%
data['clean_state'].unique()
# Out:
# array(['FL', 'IL', 'NC', 'TX', 'NV', 'CA', 'AP', 'KS', 'IN', 'MT', 'WI',
#        'MO', 'HI', 'UT', 'GA', 'WA', 'ID', 'CT', 'AL', 'ND', 'SC', 'IA',
#        'CO', 'LA', 'OR', 'SD', 'TN', 'NM', 'AZ', 'MN', 'KY', 'OK', 'NJ',
#        'NE', 'MI', 'AR', 'MS', 'NY', 'WY', 'MD', 'AK', 'VA', 'AE'],
#       dtype=object)

# %%
data['state'] = data['state'].str.upper()

# %%
data['state'] = data['state'].str.strip()
